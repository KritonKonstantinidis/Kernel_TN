# %%
import numpy as np
import time 
from matplotlib import pyplot as plt
import gpflow
from gpflow.ci_utils import ci_niter
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from TensorNetworkKernels import KernelWithTensorNetwork, KernelSpaceInducingPoints
from sklearn.cluster import KMeans

# %%
X_full, Y_full = np.load('./data/elevators/X.npy'), np.load('./data/elevators/y.npy')

x_train, x_test, y_train, y_test = train_test_split(X_full, Y_full, test_size = 0.1, random_state = 0)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.1, random_state = 0)

scaler_X = StandardScaler()
scaler_Y = StandardScaler()

x_train, x_val, x_test= scaler_X.fit_transform(x_train), scaler_X.transform(x_val), scaler_X.transform(x_test)
y_train, y_val, y_test = scaler_Y.fit_transform(y_train.reshape(-1,1)), scaler_Y.transform(y_val.reshape(-1,1)), scaler_Y.transform(y_test.reshape(-1,1))

# %% [markdown]
# # CPD Kernel

# %%
cp_rank=10
local_dim=10
batch_size=256

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(x_train.shape[0]).batch(batch_size,
                                                                                            drop_remainder=True).repeat()

kernel = KernelWithTensorNetwork(gpflow.kernels.SquaredExponential(), batch_size=batch_size,
                                 cp_rank=cp_rank,local_dim=local_dim)

M=50 # inducing points 

# Cluster Initialization of Inducing Points 
inducing_variable_kmeans = KMeans(n_clusters=M,random_state=0).fit(x_train)   
Z=inducing_variable_kmeans.cluster_centers_                           
inducing_variable_CP = kernel.CP(Z)
inducing_variable = KernelSpaceInducingPoints(inducing_variable_CP)

model= gpflow.models.SVGP(kernel, gpflow.likelihoods.Gaussian(), inducing_variable , num_data=x_train.shape[0])    
gpflow.set_trainable(model.inducing_variable, True)
model.kernel.CP.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cp__based (CP_Based)         (50, 1)                   1800
# =================================================================
# Total params: 1,800
# Trainable params: 1,800
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training

iterations = ci_niter(20000)

logf = []

train_iter=iter(train_dataset)
training_loss = model.training_loss_closure(train_iter,compile=True)

optimizer = tf.optimizers.Adam(learning_rate=1e-3)
start=time.time()

@tf.function
def optimization_step():
    optimizer.minimize(training_loss, model.trainable_variables)
    
for step in range(iterations):
    optimization_step()    
    if step % 10 == 0:
        elbo = -training_loss().numpy()
        logf.append(elbo)
    if step % 1000==0:
        print("Epoch:{}, ELBO:{}".format(step,model.elbo(data=(x_train,y_train)))) 

end=time.time()
print("Training Time :{}".format(end-start))

plt.plot(np.arange(iterations)[::10], logf)
plt.xlabel("iteration")
_ = plt.ylabel("ELBO")

train_mean, train_var = model.predict_f(x_train) 
train_elbo=model.elbo(data=(x_train,y_train))

train_mse=tf.reduce_mean(tf.losses.MSE(train_mean,y_train))

val_mean, val_var = model.predict_f(x_val)
val_elbo = model.elbo(data=(x_val,y_val))

val_mse=tf.reduce_mean(tf.losses.MSE(val_mean,y_val))

test_mean, val_var = model.predict_f(x_test)
test_elbo = model.elbo(data=(x_test,y_test))

test_mse=tf.reduce_mean(tf.losses.MSE(test_mean,y_test))


print("Train MSE:{}, Train ELBO:{}".format(train_mse,train_elbo))
print("Validation MSE:{}, Validation ELBO:{}".format(val_mse,val_elbo))
print("Test MSE:{}, Validation ELBO:{}".format(test_mse,test_elbo))
# Out:
# Epoch:0, ELBO:-25778.169601673806
# Epoch:1000, ELBO:-17221.37143780484
# Epoch:2000, ELBO:-14313.106204668407
# Epoch:3000, ELBO:-11223.372328841488
# Epoch:4000, ELBO:-9243.795038206958
# Epoch:5000, ELBO:-7823.015859798684
# Epoch:6000, ELBO:-7187.871362202071
# Epoch:7000, ELBO:-6830.310268965528
# Epoch:8000, ELBO:-6497.921758370342
# Epoch:9000, ELBO:-6281.653824470684
# Epoch:10000, ELBO:-6131.900150971947
# Epoch:11000, ELBO:-5994.771906685749
# Epoch:12000, ELBO:-5849.904298927284
# Epoch:13000, ELBO:-5771.177371994461
# Epoch:14000, ELBO:-5723.384863372726
# Epoch:15000, ELBO:-5610.560621419208
# Epoch:16000, ELBO:-5548.89385452951
# Epoch:17000, ELBO:-5471.136482055787
# Epoch:18000, ELBO:-5438.00212961965
# Epoch:19000, ELBO:-5379.276587285951
# Training Time :95.426992893219
# Train MSE:0.12811802306311112, Train ELBO:-5338.426432165823
# Validation MSE:0.22777417057146818, Validation ELBO:-10567.728952246825
# Test MSE:0.1868898770167622, Validation ELBO:-8388.943956559955

# %% [markdown]
# # Tensor Network

# %%
def local_feature_mapping(x_train,x_val,x_test,local_dim=2,unit_norm=False):
    
    n_train_samples = x_train.shape[0]
    n_val_samples = x_val.shape[0]
    n_test_samples = x_test.shape[0]
    n_features = x_train.shape[1]

    X_transformed_train_list = []
    X_transformed_val_list = []
    X_transformed_test_list = []
    
    for d in range(local_dim-1):
        X_transformed_train_list.append(x_train**(d+1))
        X_transformed_val_list.append(x_val**(d+1))
        X_transformed_test_list.append(x_test**(d+1))
         
    X_stand_train_list = [np.ones((n_train_samples,n_features))]
    X_stand_val_list = [np.ones((n_val_samples,n_features))]
    X_stand_test_list = [np.ones((n_test_samples,n_features))]
    
    for X_trans_train,X_trans_val,X_trans_test in zip(X_transformed_train_list,X_transformed_val_list,X_transformed_test_list):
         
      X_stand_train_list.append(X_trans_train)
      X_stand_val_list.append(X_trans_val) 
      X_stand_test_list.append(X_trans_test)
        
    x_train_processed= np.transpose(X_stand_train_list,(1, 2, 0))
    x_val_processed= np.transpose(X_stand_val_list,(1, 2, 0))
    x_test_processed = np.transpose(X_stand_test_list,(1, 2, 0))

    if(unit_norm==True):
      norms_train = np.sqrt(np.sum(x_train_processed**2,axis=-1,keepdims=True))
      x_train_processed = np.divide(x_train_processed,norms_train)

      norms_val = np.sqrt(np.sum(x_val_processed**2,axis=-1,keepdims=True))
      x_val_processed = np.divide(x_val_processed,norms_val)
    
      norms_test = np.sqrt(np.sum(x_test_processed**2,axis=-1,keepdims=True))
      x_test_processed = np.divide(x_test_processed,norms_test)

    return x_train_processed, x_val_processed, x_test_processed

# %%
from CP_Model import CP_Based
from tensorflow.keras.models import Sequential
import pandas as pd 
from tensorflow import keras 

x_train_processed,x_val_processed,x_test_processed=local_feature_mapping(x_train,x_val,x_test,local_dim=local_dim,unit_norm=True)

model=Sequential()
model.add(CP_Based(units=1,activation=None,cp_rank=cp_rank,local_dim=local_dim,

                    initializer=keras.initializers.TruncatedNormal(mean=0, stddev=0.5)))

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(optimizer, loss=tf.keras.losses.MeanSquaredError())

start = time.time()
history=model.fit(x_train_processed, y_train, epochs=300, batch_size=256,validation_data=(x_val_processed,y_val))
end = time.time()
model.summary()

train_loss=min(history.history['loss'])
val_loss=min(history.history['val_loss'])
print('train loss:{}'.format(train_loss))
print('validation loss:{}'.format(val_loss))

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.show()

print('Training time:{}'.format(end-start))
print('Test MSE:{}'.format(model.evaluate(x_test_processed,y_test)))
# Out:
# Epoch 1/300
# 53/53 [==============================] - 0s 5ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 2/300
# 53/53 [==============================] - 0s 3ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 3/300
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 4/300
# 53/53 [==============================] - 0s 3ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 5/300
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 6/300
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 7/300
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 8/300
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 9/300
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 10/300
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 11/300
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 12/300
# 53/53 [==============================] - 0s 3ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 13/300
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 14/300
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 15/300
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 16/300
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 17/300
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 18/300
# 53/53 [==============================] - 0s 3ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 19/300
# 53/53 [==============================] - 0s 3ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 20/300
# 53/53 [==============================] - 0s 3ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 21/300
# 53/53 [==============================] - 0s 3ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 22/300
# 53/53 [==============================] - 0s 4ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 23/300
# 53/53 [==============================] - 0s 4ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 24/300
# 53/53 [==============================] - 0s 3ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 25/300
# 53/53 [==============================] - 0s 3ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 26/300
# 53/53 [==============================] - 0s 8ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 27/300
# 53/53 [==============================] - 0s 3ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 28/300
# 53/53 [==============================] - 0s 6ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 29/300
# 53/53 [==============================] - 0s 5ms/step - loss: 1.0000 - val_loss: 0.9825
# Epoch 30/300
# 53/53 [==============================] - 0s 4ms/step - loss: 0.9998 - val_loss: 0.9825
# Epoch 31/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.9990 - val_loss: 0.9825
# Epoch 32/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.9991 - val_loss: 0.9825
# Epoch 33/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.9986 - val_loss: 0.9825
# Epoch 34/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.9984 - val_loss: 0.9825
# Epoch 35/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.9984 - val_loss: 0.9824
# Epoch 36/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.9981 - val_loss: 0.9819
# Epoch 37/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.9816 - val_loss: 0.9444
# Epoch 38/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.9479 - val_loss: 0.9218
# Epoch 39/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.9239 - val_loss: 0.9033
# Epoch 40/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.9016 - val_loss: 0.8820
# Epoch 41/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.8806 - val_loss: 0.8654
# Epoch 42/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.8654 - val_loss: 0.8480
# Epoch 43/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.8531 - val_loss: 0.8339
# Epoch 44/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.8424 - val_loss: 0.8218
# Epoch 45/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.8329 - val_loss: 0.8108
# Epoch 46/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.8233 - val_loss: 0.7990
# Epoch 47/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.8157 - val_loss: 0.7890
# Epoch 48/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.8069 - val_loss: 0.7744
# Epoch 49/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7981 - val_loss: 0.7633
# Epoch 50/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7898 - val_loss: 0.7528
# Epoch 51/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7814 - val_loss: 0.7428
# Epoch 52/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7721 - val_loss: 0.7360
# Epoch 53/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7639 - val_loss: 0.7274
# Epoch 54/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7550 - val_loss: 0.7207
# Epoch 55/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7469 - val_loss: 0.7180
# Epoch 56/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7389 - val_loss: 0.7104
# Epoch 57/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7325 - val_loss: 0.7063
# Epoch 58/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7253 - val_loss: 0.7048
# Epoch 59/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7182 - val_loss: 0.7024
# Epoch 60/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7121 - val_loss: 0.6986
# Epoch 61/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7056 - val_loss: 0.6918
# Epoch 62/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6994 - val_loss: 0.6874
# Epoch 63/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6931 - val_loss: 0.6867
# Epoch 64/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6847 - val_loss: 0.6848
# Epoch 65/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6762 - val_loss: 0.6823
# Epoch 66/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6661 - val_loss: 0.6796
# Epoch 67/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6533 - val_loss: 0.6719
# Epoch 68/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6361 - val_loss: 0.6628
# Epoch 69/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6151 - val_loss: 0.6575
# Epoch 70/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5905 - val_loss: 0.6520
# Epoch 71/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5702 - val_loss: 0.6332
# Epoch 72/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5549 - val_loss: 0.6154
# Epoch 73/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5444 - val_loss: 0.6162
# Epoch 74/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5348 - val_loss: 0.6009
# Epoch 75/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5273 - val_loss: 0.5944
# Epoch 76/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5210 - val_loss: 0.5870
# Epoch 77/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5149 - val_loss: 0.5771
# Epoch 78/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5097 - val_loss: 0.5708
# Epoch 79/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5052 - val_loss: 0.5727
# Epoch 80/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5011 - val_loss: 0.5605
# Epoch 81/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4965 - val_loss: 0.5564
# Epoch 82/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4922 - val_loss: 0.5511
# Epoch 83/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4887 - val_loss: 0.5495
# Epoch 84/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4846 - val_loss: 0.5476
# Epoch 85/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4812 - val_loss: 0.5346
# Epoch 86/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4718 - val_loss: 0.5272
# Epoch 87/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4601 - val_loss: 0.5076
# Epoch 88/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4476 - val_loss: 0.4957
# Epoch 89/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4334 - val_loss: 0.4722
# Epoch 90/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4205 - val_loss: 0.4584
# Epoch 91/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4107 - val_loss: 0.4507
# Epoch 92/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4017 - val_loss: 0.4408
# Epoch 93/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3934 - val_loss: 0.4348
# Epoch 94/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3861 - val_loss: 0.4293
# Epoch 95/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3790 - val_loss: 0.4243
# Epoch 96/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3720 - val_loss: 0.4208
# Epoch 97/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3657 - val_loss: 0.4129
# Epoch 98/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3597 - val_loss: 0.4047
# Epoch 99/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3542 - val_loss: 0.3981
# Epoch 100/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3481 - val_loss: 0.3925
# Epoch 101/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3438 - val_loss: 0.3882
# Epoch 102/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3390 - val_loss: 0.3831
# Epoch 103/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3353 - val_loss: 0.3769
# Epoch 104/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3316 - val_loss: 0.3788
# Epoch 105/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3271 - val_loss: 0.3746
# Epoch 106/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3243 - val_loss: 0.3661
# Epoch 107/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3204 - val_loss: 0.3648
# Epoch 108/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3171 - val_loss: 0.3597
# Epoch 109/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3140 - val_loss: 0.3610
# Epoch 110/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3111 - val_loss: 0.3544
# Epoch 111/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3084 - val_loss: 0.3522
# Epoch 112/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3060 - val_loss: 0.3474
# Epoch 113/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3037 - val_loss: 0.3494
# Epoch 114/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.3008 - val_loss: 0.3444
# Epoch 115/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2984 - val_loss: 0.3420
# Epoch 116/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2958 - val_loss: 0.3407
# Epoch 117/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2939 - val_loss: 0.3336
# Epoch 118/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2913 - val_loss: 0.3358
# Epoch 119/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2896 - val_loss: 0.3307
# Epoch 120/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2875 - val_loss: 0.3313
# Epoch 121/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2855 - val_loss: 0.3305
# Epoch 122/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2833 - val_loss: 0.3283
# Epoch 123/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2815 - val_loss: 0.3231
# Epoch 124/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2798 - val_loss: 0.3201
# Epoch 125/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2774 - val_loss: 0.3189
# Epoch 126/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2759 - val_loss: 0.3188
# Epoch 127/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2736 - val_loss: 0.3146
# Epoch 128/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2718 - val_loss: 0.3124
# Epoch 129/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2701 - val_loss: 0.3126
# Epoch 130/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2680 - val_loss: 0.3124
# Epoch 131/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2664 - val_loss: 0.3068
# Epoch 132/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2653 - val_loss: 0.3081
# Epoch 133/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2632 - val_loss: 0.3070
# Epoch 134/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2620 - val_loss: 0.3099
# Epoch 135/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2603 - val_loss: 0.3030
# Epoch 136/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2578 - val_loss: 0.2984
# Epoch 137/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2563 - val_loss: 0.3007
# Epoch 138/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2554 - val_loss: 0.2959
# Epoch 139/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2533 - val_loss: 0.2955
# Epoch 140/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2520 - val_loss: 0.2901
# Epoch 141/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2502 - val_loss: 0.2923
# Epoch 142/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2483 - val_loss: 0.2913
# Epoch 143/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2475 - val_loss: 0.2899
# Epoch 144/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2456 - val_loss: 0.2885
# Epoch 145/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2442 - val_loss: 0.2836
# Epoch 146/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2427 - val_loss: 0.2839
# Epoch 147/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2415 - val_loss: 0.2807
# Epoch 148/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2404 - val_loss: 0.2813
# Epoch 149/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2394 - val_loss: 0.2809
# Epoch 150/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2381 - val_loss: 0.2783
# Epoch 151/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2369 - val_loss: 0.2758
# Epoch 152/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2376 - val_loss: 0.2753
# Epoch 153/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2347 - val_loss: 0.2731
# Epoch 154/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2349 - val_loss: 0.2738
# Epoch 155/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2336 - val_loss: 0.2727
# Epoch 156/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2318 - val_loss: 0.2741
# Epoch 157/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2308 - val_loss: 0.2699
# Epoch 158/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2302 - val_loss: 0.2677
# Epoch 159/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2295 - val_loss: 0.2681
# Epoch 160/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2278 - val_loss: 0.2656
# Epoch 161/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2278 - val_loss: 0.2669
# Epoch 162/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2264 - val_loss: 0.2653
# Epoch 163/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2257 - val_loss: 0.2644
# Epoch 164/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2240 - val_loss: 0.2651
# Epoch 165/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2240 - val_loss: 0.2640
# Epoch 166/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2224 - val_loss: 0.2632
# Epoch 167/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2216 - val_loss: 0.2597
# Epoch 168/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2215 - val_loss: 0.2608
# Epoch 169/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2204 - val_loss: 0.2594
# Epoch 170/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2197 - val_loss: 0.2608
# Epoch 171/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2184 - val_loss: 0.2560
# Epoch 172/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2179 - val_loss: 0.2561
# Epoch 173/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2169 - val_loss: 0.2557
# Epoch 174/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2162 - val_loss: 0.2535
# Epoch 175/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2155 - val_loss: 0.2545
# Epoch 176/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2146 - val_loss: 0.2541
# Epoch 177/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2148 - val_loss: 0.2532
# Epoch 178/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2139 - val_loss: 0.2538
# Epoch 179/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2125 - val_loss: 0.2499
# Epoch 180/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2117 - val_loss: 0.2506
# Epoch 181/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2114 - val_loss: 0.2511
# Epoch 182/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2118 - val_loss: 0.2492
# Epoch 183/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2103 - val_loss: 0.2487
# Epoch 184/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2104 - val_loss: 0.2481
# Epoch 185/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2098 - val_loss: 0.2491
# Epoch 186/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2087 - val_loss: 0.2474
# Epoch 187/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2083 - val_loss: 0.2483
# Epoch 188/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2080 - val_loss: 0.2473
# Epoch 189/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2069 - val_loss: 0.2480
# Epoch 190/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2067 - val_loss: 0.2436
# Epoch 191/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2064 - val_loss: 0.2439
# Epoch 192/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2056 - val_loss: 0.2447
# Epoch 193/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2055 - val_loss: 0.2454
# Epoch 194/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2057 - val_loss: 0.2441
# Epoch 195/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2046 - val_loss: 0.2402
# Epoch 196/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2033 - val_loss: 0.2465
# Epoch 197/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2043 - val_loss: 0.2423
# Epoch 198/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2027 - val_loss: 0.2443
# Epoch 199/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2021 - val_loss: 0.2432
# Epoch 200/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2019 - val_loss: 0.2400
# Epoch 201/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2013 - val_loss: 0.2425
# Epoch 202/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2009 - val_loss: 0.2405
# Epoch 203/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2008 - val_loss: 0.2383
# Epoch 204/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2002 - val_loss: 0.2368
# Epoch 205/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.2000 - val_loss: 0.2368
# Epoch 206/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1994 - val_loss: 0.2374
# Epoch 207/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1994 - val_loss: 0.2363
# Epoch 208/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1980 - val_loss: 0.2369
# Epoch 209/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1980 - val_loss: 0.2371
# Epoch 210/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1982 - val_loss: 0.2367
# Epoch 211/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1970 - val_loss: 0.2394
# Epoch 212/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1971 - val_loss: 0.2379
# Epoch 213/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1970 - val_loss: 0.2342
# Epoch 214/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1956 - val_loss: 0.2335
# Epoch 215/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1956 - val_loss: 0.2327
# Epoch 216/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1948 - val_loss: 0.2338
# Epoch 217/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1944 - val_loss: 0.2319
# Epoch 218/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1941 - val_loss: 0.2319
# Epoch 219/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1932 - val_loss: 0.2330
# Epoch 220/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1935 - val_loss: 0.2328
# Epoch 221/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1936 - val_loss: 0.2345
# Epoch 222/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1935 - val_loss: 0.2298
# Epoch 223/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1923 - val_loss: 0.2287
# Epoch 224/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1911 - val_loss: 0.2297
# Epoch 225/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1909 - val_loss: 0.2327
# Epoch 226/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1912 - val_loss: 0.2268
# Epoch 227/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1901 - val_loss: 0.2291
# Epoch 228/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1898 - val_loss: 0.2278
# Epoch 229/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1892 - val_loss: 0.2275
# Epoch 230/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1885 - val_loss: 0.2269
# Epoch 231/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1883 - val_loss: 0.2275
# Epoch 232/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1879 - val_loss: 0.2256
# Epoch 233/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1877 - val_loss: 0.2318
# Epoch 234/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1882 - val_loss: 0.2252
# Epoch 235/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1870 - val_loss: 0.2282
# Epoch 236/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1868 - val_loss: 0.2271
# Epoch 237/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1869 - val_loss: 0.2275
# Epoch 238/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1865 - val_loss: 0.2257
# Epoch 239/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1859 - val_loss: 0.2247
# Epoch 240/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1861 - val_loss: 0.2251
# Epoch 241/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1853 - val_loss: 0.2259
# Epoch 242/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1856 - val_loss: 0.2244
# Epoch 243/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1843 - val_loss: 0.2239
# Epoch 244/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1844 - val_loss: 0.2227
# Epoch 245/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1843 - val_loss: 0.2248
# Epoch 246/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1834 - val_loss: 0.2257
# Epoch 247/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1845 - val_loss: 0.2256
# Epoch 248/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1834 - val_loss: 0.2224
# Epoch 249/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1829 - val_loss: 0.2247
# Epoch 250/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1826 - val_loss: 0.2214
# Epoch 251/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1823 - val_loss: 0.2216
# Epoch 252/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1829 - val_loss: 0.2220
# Epoch 253/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1824 - val_loss: 0.2206
# Epoch 254/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1823 - val_loss: 0.2219
# Epoch 255/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1817 - val_loss: 0.2242
# Epoch 256/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1812 - val_loss: 0.2218
# Epoch 257/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1811 - val_loss: 0.2283
# Epoch 258/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1811 - val_loss: 0.2205
# Epoch 259/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1805 - val_loss: 0.2215
# Epoch 260/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1806 - val_loss: 0.2190
# Epoch 261/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1803 - val_loss: 0.2185
# Epoch 262/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1794 - val_loss: 0.2202
# Epoch 263/300
# 53/53 [==============================] - 0s 4ms/step - loss: 0.1805 - val_loss: 0.2188
# Epoch 264/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1799 - val_loss: 0.2187
# Epoch 265/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1788 - val_loss: 0.2186
# Epoch 266/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1791 - val_loss: 0.2246
# Epoch 267/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1790 - val_loss: 0.2189
# Epoch 268/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1784 - val_loss: 0.2176
# Epoch 269/300
# 53/53 [==============================] - 0s 4ms/step - loss: 0.1783 - val_loss: 0.2167
# Epoch 270/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1783 - val_loss: 0.2186
# Epoch 271/300
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1776 - val_loss: 0.2197
# Epoch 272/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1774 - val_loss: 0.2176
# Epoch 273/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1782 - val_loss: 0.2235
# Epoch 274/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1769 - val_loss: 0.2180
# Epoch 275/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1775 - val_loss: 0.2196
# Epoch 276/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1774 - val_loss: 0.2179
# Epoch 277/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1766 - val_loss: 0.2166
# Epoch 278/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1760 - val_loss: 0.2181
# Epoch 279/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1764 - val_loss: 0.2158
# Epoch 280/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1761 - val_loss: 0.2155
# Epoch 281/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1755 - val_loss: 0.2158
# Epoch 282/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1763 - val_loss: 0.2168
# Epoch 283/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1754 - val_loss: 0.2172
# Epoch 284/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1752 - val_loss: 0.2144
# Epoch 285/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1759 - val_loss: 0.2155
# Epoch 286/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1752 - val_loss: 0.2149
# Epoch 287/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1747 - val_loss: 0.2135
# Epoch 288/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1754 - val_loss: 0.2183
# Epoch 289/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1743 - val_loss: 0.2136
# Epoch 290/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1747 - val_loss: 0.2151
# Epoch 291/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1741 - val_loss: 0.2132
# Epoch 292/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1740 - val_loss: 0.2145
# Epoch 293/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1738 - val_loss: 0.2146
# Epoch 294/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1741 - val_loss: 0.2130
# Epoch 295/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1746 - val_loss: 0.2185
# Epoch 296/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1734 - val_loss: 0.2166
# Epoch 297/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1736 - val_loss: 0.2146
# Epoch 298/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1730 - val_loss: 0.2147
# Epoch 299/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1728 - val_loss: 0.2176
# Epoch 300/300
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1729 - val_loss: 0.2122
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# cp__based_6 (CP_Based)       (None, 1)                 1800
# =================================================================
# Total params: 1,800
# Trainable params: 1,800
# Non-trainable params: 0
# _________________________________________________________________
# train loss:0.1728341281414032
# validation loss:0.2122277021408081
# Training time:36.26968502998352
# 52/52 [==============================] - 0s 604us/step - loss: 0.2050
# Test MSE:0.2050376683473587

# %% [markdown]
# # Deep Kernel

# %%
from DeepKernels import DeepKernel, KernelSpaceInducingPoints

batch_size=256
kernel = DeepKernel(gpflow.kernels.SquaredExponential(), batch_size=batch_size)

M=50 # inducing points 

# Cluster Initialization of Inducing Points 
inducing_variable_kmeans = KMeans(n_clusters=M,random_state=0).fit(x_train)   
Z=inducing_variable_kmeans.cluster_centers_                           
inducing_variable_CP = kernel.CP(Z)
inducing_variable = KernelSpaceInducingPoints(inducing_variable_CP)


model= gpflow.models.SVGP(kernel, gpflow.likelihoods.Gaussian(), inducing_variable , num_data=x_train.shape[0])    
gpflow.set_trainable(model.inducing_variable, True)
model.kernel.CP.summary()

# Training

iterations = ci_niter(20000)

logf = []

train_iter=iter(train_dataset)
training_loss = model.training_loss_closure(train_iter,compile=True)

optimizer = tf.optimizers.Adam(learning_rate=1e-3)
start=time.time()

@tf.function
def optimization_step():
    optimizer.minimize(training_loss, model.trainable_variables)
    
for step in range(iterations):
    optimization_step()    
    if step % 10 == 0:
        elbo = -training_loss().numpy()
        logf.append(elbo)
    if step % 1000==0:
        print("Epoch:{}, ELBO:{}".format(step,model.elbo(data=(x_train,y_train)))) 

end=time.time()
print("Training Time :{}".format(end-start))

plt.plot(np.arange(iterations)[::10], logf)
plt.xlabel("iteration")
_ = plt.ylabel("ELBO")

train_mean, train_var = model.predict_f(x_train) 
train_elbo=model.elbo(data=(x_train,y_train))

train_mse=tf.reduce_mean(tf.losses.MSE(train_mean,y_train))

val_mean, val_var = model.predict_f(x_val)
val_elbo = model.elbo(data=(x_val,y_val))

val_mse=tf.reduce_mean(tf.losses.MSE(val_mean,y_val))

test_mean, val_var = model.predict_f(x_test)
test_elbo = model.elbo(data=(x_test,y_test))

test_mse=tf.reduce_mean(tf.losses.MSE(test_mean,y_test))


print("Train MSE:{}, Train ELBO:{}".format(train_mse,train_elbo))
print("Validation MSE:{}, Validation ELBO:{}".format(val_mse,val_elbo))
print("Test MSE:{}, Validation ELBO:{}".format(test_mse,test_elbo))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (50, 35)                  665
# _________________________________________________________________
# dense_1 (Dense)              (50, 30)                  1080
# _________________________________________________________________
# dense_2 (Dense)              (50, 1)                   31
# =================================================================
# Total params: 1,776
# Trainable params: 1,776
# Non-trainable params: 0
# _________________________________________________________________
# Epoch:0, ELBO:-25769.788128490498
# Epoch:1000, ELBO:-10233.48376144745
# Epoch:2000, ELBO:-5930.6097156788765
# Epoch:3000, ELBO:-4598.754133208631
# Epoch:4000, ELBO:-4255.853674166433
# Epoch:5000, ELBO:-4218.445939012285
# Epoch:6000, ELBO:-4012.1237002988396
# Epoch:7000, ELBO:-3921.513854480044
# Epoch:8000, ELBO:-4008.4707961663776
# Epoch:9000, ELBO:-3854.7141478664907
# Epoch:10000, ELBO:-3786.3703658782792
# Epoch:11000, ELBO:-3870.596059035544
# Epoch:12000, ELBO:-3707.6054537191994
# Epoch:13000, ELBO:-3774.1934944246436
# Epoch:14000, ELBO:-3682.419602294926
# Epoch:15000, ELBO:-3854.723921953491
# Epoch:16000, ELBO:-3614.94188685418
# Epoch:17000, ELBO:-3685.566383899456
# Epoch:18000, ELBO:-3588.7604606948425
# Epoch:19000, ELBO:-3545.2953095193484
# Training Time :53.389317750930786
# Train MSE:0.09822926813886942, Train ELBO:-3530.5232445658403
# Validation MSE:0.13630558005305282, Validation ELBO:-6086.998881212345
# Test MSE:0.13137126851144884, Validation ELBO:-5812.269496292439

# %% [markdown]
# # Gaussian Process with ARD RBF Kernel

# %%
kernel= gpflow.kernels.SquaredExponential(lengthscales=[0.1]*x_train.shape[1]) #  ARD

M=50 # inducing points 

# Cluster Initialization of Inducing Points 
inducing_variable_kmeans = KMeans(n_clusters=M,random_state=0).fit(x_train)   
Z=inducing_variable_kmeans.cluster_centers_    

model = gpflow.models.SVGP(kernel, gpflow.likelihoods.Gaussian(), Z, num_data=x_train.shape[0])
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).repeat().shuffle(x_train.shape[0])

minibatch_size = 256
gpflow.set_trainable(model.inducing_variable, True)


def run_adam(model, iterations):
    """
    Utility function running the Adam optimizer

    :param model: GPflow model
    :param interations: number of iterations
    """
    # Create an Adam Optimizer action
    logf = []
    train_iter = iter(train_dataset.batch(minibatch_size))
    training_loss = model.training_loss_closure(train_iter, compile=True)
    optimizer = tf.optimizers.Adam(learning_rate=1e-3)

    @tf.function
    def optimization_step():
        optimizer.minimize(training_loss, model.trainable_variables)

    for step in range(iterations):
        optimization_step()
        if step % 10 == 0:
            elbo = -training_loss().numpy()
            logf.append(elbo)
    return logf

maxiter = ci_niter(10000)

logf = run_adam(model, maxiter)
plt.plot(np.arange(maxiter)[::10], logf)
plt.xlabel("iteration")
_ = plt.ylabel("ELBO")

train_mean, train_var = model.predict_f(x_train) 
train_elbo=model.elbo(data=(x_train,y_train))

train_mse=tf.reduce_mean(tf.losses.MSE(train_mean,y_train))

val_mean, val_var = model.predict_f(x_val)
val_elbo = model.elbo(data=(x_val,y_val))

val_mse=tf.reduce_mean(tf.losses.MSE(val_mean,y_val))

test_mean, val_var = model.predict_f(x_test)
test_elbo = model.elbo(data=(x_test,y_test))

test_mse=tf.reduce_mean(tf.losses.MSE(test_mean,y_test))


print("Train MSE:{}, Train ELBO:{}".format(train_mse,train_elbo))
print("Validation MSE:{}, Validation ELBO:{}".format(val_mse,val_elbo))
print("Test MSE:{}, Validation ELBO:{}".format(test_mse,test_elbo))
# Out:
# Train MSE:0.21918109755069434, Train ELBO:-10266.669151901753
# Validation MSE:0.2529329664430518, Validation ELBO:-11056.848680034946
# Test MSE:0.2388905794576891, Validation ELBO:-10717.160660360409
